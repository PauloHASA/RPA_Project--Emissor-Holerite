# %%
import pyautogui
import time
import pandas as pd 
import os
import win32com.client as win32

outlook = win32.Dispatch('outlook.application')
bd_df = pd.read_csv('Bd_Fucionarios_WBG.csv', sep=';')

#Emitido o relatorio 
pyautogui.click(x=47, y=17)

time.sleep(1)
x, y, altura, largura = pyautogui.locateOnScreen('relatorio.png')
pyautogui.click(x + largura/2, y + altura/2)

time.sleep(1)
#x, y, altura, largura = pyautogui.locateOnScreen('mensais.png')
#pyautogui.click(x + largura/2, y + altura/2)
pyautogui.click(x=314, y=61)

time.sleep(1)
#x, y, altura, largura = pyautogui.locateOnScreen('recibo de pgto.png')
#pyautogui.click(x + largura/2, y + altura/2)
pyautogui.click(x=583, y=83)

time.sleep(1)
#x, y, altura, largura = pyautogui.locateOnScreen()
#pyautogui.click(x + altura)
pyautogui.click(x=866, y=85)
time.sleep(1)
pyautogui.click(x=667, y=268)

#time.sleep(1)
#pyautogui.click(x=696, y=340) #2º via em nova pagina

#time.sleep(1)
#pyautogui.click(x=719, y=473)#Quebra por

#time.sleep(1)
#pyautogui.click(x=730, y=523)#Setor

time.sleep(1)
pyautogui.click(x=598, y=328)#Botão Funcionários

        #Buscando funcionario 
for codigo in bd_df['Código']:#Acesso ao Banco de dados
    
#Funcionario - Eliana França 
    if codigo==1:
        cod = 0
        
        #Buscando no sistema 
    #Inicio - 
        time.sleep(1)
        pyautogui.click(x=497, y=366)

        time.sleep(1)
        pyautogui.click(x=720, y=402)

        time.sleep(1)
        pyautogui.click(x=351, y=632)
    #Fim
    #Salvando o Arquivo - Inicio
        time.sleep(1)
        pyautogui.click(x=629, y=646)#imprimir

        time.sleep(3)
        pyautogui.click(x=90, y=15)
    
        time.sleep(3)
        pyautogui.click(x=861, y=673)

        time.sleep(3)
        pyautogui.click(x=1034, y=687)

        time.sleep(2)
        pyautogui.click(x=204, y=376)

        time.sleep(2)
        pyautogui.write('Eliana Franca')
        pyautogui.press('enter')

        time.sleep(2)
        pyautogui.click(x=1433, y=18)
    #Salvando o Arquivo - FIM
    #Removendo selecionados -  Inicio 
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários

        time.sleep(2)
        pyautogui.click(x=725, y=502)#Removendo selecionados

        time.sleep(1)
        pyautogui.click(x=351, y=632)#Botão - OK
    #Removendo selecionados -  FIM 
        
        #Identificar o arquivo mais recente na pasta - Inicio
        caminho = r'C:\Users\Legalização2\Downloads'
        lista_arquivos = os.listdir(caminho)

        lista_datas = []
        for arquivos in lista_arquivos:
            #Descobrir a data desse arquivo
            data = os.path.getmtime(f'{caminho}/{arquivos}')
            lista_datas.append((data, arquivos))
    
        lista_datas.sort(reverse=True)   
        ultimo_arquivo = lista_datas[0]
        arquivo = ultimo_arquivo[1]
        #Fim
        
        #Validação do Arquivo - Inicio
        if 'Eliana' in arquivo:
            
            #Enviando Holerite por email - Inicio
            email = bd_df.loc[cod, 'Email'] #Localizar o e-mail

            mail = outlook.CreateItem(0)
            mail.To = email
            mail.subject = 'Holerite - Eliana França'
            mail.Body = ''
            attachment  = f'{caminho}/{arquivo}'
            mail.Attachments.Add(attachment)
        
            mail.Send()
            
            print('Holerite enviado - Eliana França')
        else:
            continue
            print('Erro no envio do Holerite da Eliana França')

            #Enviando Holerite por email - Fim            
        #Validação do Arquivo - Fim
        
#Funcionario - Regina Felipini         
    elif codigo==22:
        cod = 1   
        
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários
        
                #Buscando no sistema 
    #Inicio - 
        time.sleep(1)
        pyautogui.click(x=351, y=384)#Troque essa posição 

        time.sleep(1)
        pyautogui.click(x=720, y=402)

        time.sleep(1)
        pyautogui.click(x=351, y=632)
    #Fim
    #Salvando o Arquivo - Inicio
        time.sleep(2)
        pyautogui.click(x=629, y=646)#imprimir

        time.sleep(4)
        pyautogui.click(x=90, y=15)
    
        time.sleep(3)
        pyautogui.click(x=861, y=673)

        time.sleep(3)
        pyautogui.click(x=1034, y=687)

        time.sleep(3)
        pyautogui.click(x=204, y=376)

        time.sleep(3)
        pyautogui.write('Regina Felipini')
        pyautogui.press('enter')

        time.sleep(2)
        pyautogui.click(x=1433, y=18)
    #Salvando o Arquivo - FIM
    #Removendo selecionados -  Inicio 
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários

        time.sleep(2)
        pyautogui.click(x=725, y=502)#Removendo selecionados

        time.sleep(1)
        pyautogui.click(x=351, y=632)#Botão - OK
    #Removendo selecionados -  FIM

        #Identificar o arquivo mais recente na pasta - Inicio
        caminho = r'C:\Users\Legalização2\Downloads'
        lista_arquivos = os.listdir(caminho)

        lista_datas = []
        for arquivos in lista_arquivos:
            #Descobrir a data desse arquivo
            data = os.path.getmtime(f'{caminho}/{arquivos}')
            lista_datas.append((data, arquivos))
    
        lista_datas.sort(reverse=True)   
        ultimo_arquivo = lista_datas[0]
        arquivo = ultimo_arquivo[1]
        #Fim

        #Validação do Arquivo - Inicio
        if 'Regina Felipini' in arquivo:
            
            #Enviando Holerite por email - Inicio
            email = bd_df.loc[cod, 'Email'] #Localizar o e-mail

            mail = outlook.CreateItem(0)
            mail.To = email
            mail.subject = 'Holerite - Regina Felipini'
            mail.Body = ''
            attachment  = f'{caminho}/{arquivo}'
            mail.Attachments.Add(attachment)
        
            mail.Send()
            
            print('Holerite enviado - Regina Felipini')
        else:
            continue
            print('Erro no envio do Holerite da Regina Felipini')

            #Enviando Holerite por email - Fim            
        #Validação do Arquivo - Fim

#Funcionario - Juliana Gomes         
    elif codigo==42:
        cod = 2   
        
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários
        
                #Buscando no sistema 
    #Inicio - 
        time.sleep(1)
        pyautogui.click(x=350, y=403)#Troque essa posição 

        time.sleep(1)
        pyautogui.click(x=720, y=402)

        time.sleep(1)
        pyautogui.click(x=351, y=632)
    #Fim
    #Salvando o Arquivo - Inicio
        time.sleep(1)
        pyautogui.click(x=629, y=646)#imprimir

        time.sleep(4)
        pyautogui.click(x=90, y=15)
    
        time.sleep(3)
        pyautogui.click(x=861, y=673)

        time.sleep(3)
        pyautogui.click(x=1034, y=687)

        time.sleep(3)
        pyautogui.click(x=204, y=376)

        time.sleep(3)
        pyautogui.write('Juliana Gomes')
        pyautogui.press('enter')

        time.sleep(2)
        pyautogui.click(x=1433, y=18)
    #Salvando o Arquivo - FIM
    #Removendo selecionados -  Inicio 
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários

        time.sleep(2)
        pyautogui.click(x=725, y=502)#Removendo selecionados

        time.sleep(1)
        pyautogui.click(x=351, y=632)#Botão - OK
    #Removendo selecionados -  FIM

        #Identificar o arquivo mais recente na pasta - Inicio
        caminho = r'C:\Users\Legalização2\Downloads'
        lista_arquivos = os.listdir(caminho)

        lista_datas = []
        for arquivos in lista_arquivos:
            #Descobrir a data desse arquivo
            data = os.path.getmtime(f'{caminho}/{arquivos}')
            lista_datas.append((data, arquivos))
    
        lista_datas.sort(reverse=True)   
        ultimo_arquivo = lista_datas[0]
        arquivo = ultimo_arquivo[1]
        #Fim

        #Validação do Arquivo - Inicio
        if 'Juliana Gomes' in arquivo:
            
            #Enviando Holerite por email - Inicio
            email = bd_df.loc[cod, 'Email'] #Localizar o e-mail

            mail = outlook.CreateItem(0)
            mail.To = email
            mail.subject = 'Holerite - Juliana Gomes'
            mail.Body = ''
            attachment  = f'{caminho}/{arquivo}'
            mail.Attachments.Add(attachment)
        
            mail.Send()
            
            print('Holerite enviado - Juliana Gomes')
        else:
            continue
            print('Erro no envio do Holerite da Juliana Gomes')

            #Enviando Holerite por email - Fim            
        #Validação do Arquivo - Fim
        
#Funcionario - Miriam Vieira         
    elif codigo==48:
        cod = 3   
        
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários
        
                #Buscando no sistema 
    #Inicio - 
        time.sleep(1)
        pyautogui.click(x=351, y=417)#Troque essa posição 

        time.sleep(1)
        pyautogui.click(x=720, y=402)

        time.sleep(1)
        pyautogui.click(x=351, y=632)
    #Fim
    #Salvando o Arquivo - Inicio
        time.sleep(1)
        pyautogui.click(x=629, y=646)#imprimir

        time.sleep(4)
        pyautogui.click(x=90, y=15)
    
        time.sleep(3)
        pyautogui.click(x=861, y=673)

        time.sleep(3)
        pyautogui.click(x=1034, y=687)

        time.sleep(3)
        pyautogui.click(x=204, y=376)

        time.sleep(3)
        pyautogui.write('Miriam Vieira')
        pyautogui.press('enter')

        time.sleep(2)
        pyautogui.click(x=1433, y=18)
    #Salvando o Arquivo - FIM
    #Removendo selecionados -  Inicio 
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários

        time.sleep(2)
        pyautogui.click(x=725, y=502)#Removendo selecionados

        time.sleep(1)
        pyautogui.click(x=351, y=632)#Botão - OK
    #Removendo selecionados -  FIM

        #Identificar o arquivo mais recente na pasta - Inicio
        caminho = r'C:\Users\Legalização2\Downloads'
        lista_arquivos = os.listdir(caminho)

        lista_datas = []
        for arquivos in lista_arquivos:
            #Descobrir a data desse arquivo
            data = os.path.getmtime(f'{caminho}/{arquivos}')
            lista_datas.append((data, arquivos))
    
        lista_datas.sort(reverse=True)   
        ultimo_arquivo = lista_datas[0]
        arquivo = ultimo_arquivo[1]
        #Fim

        #Validação do Arquivo - Inicio
        if 'Miriam Vieira' in arquivo:
            
            #Enviando Holerite por email - Inicio
            email = bd_df.loc[cod, 'Email'] #Localizar o e-mail

            mail = outlook.CreateItem(0)
            mail.To = email
            mail.subject = 'Holerite - Miriam Vieira'
            mail.Body = ''
            attachment  = f'{caminho}/{arquivo}'
            mail.Attachments.Add(attachment)
        
            mail.Send()
            
            print('Holerite enviado - Miriam Vieira')
        else:
            continue
            print('Erro no envio do Holerite da Miriam Vieira')

            #Enviando Holerite por email - Fim            
        #Validação do Arquivo - Fim
        
#Funcionario - Erika Goes         
    elif codigo==59:
        cod = 4   
        
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários
        
                #Buscando no sistema 
    #Inicio - 
        time.sleep(1)
        pyautogui.click(x=352, y=450)#Troque essa posição 

        time.sleep(1)
        pyautogui.click(x=720, y=402)

        time.sleep(1)
        pyautogui.click(x=351, y=632)
    #Fim
    #Salvando o Arquivo - Inicio
        time.sleep(1)
        pyautogui.click(x=629, y=646)#imprimir

        time.sleep(4)
        pyautogui.click(x=90, y=15)
    
        time.sleep(3)
        pyautogui.click(x=861, y=673)

        time.sleep(3)
        pyautogui.click(x=1034, y=687)

        time.sleep(3)
        pyautogui.click(x=204, y=376)

        time.sleep(3)
        pyautogui.write('Erika Goes')
        pyautogui.press('enter')

        time.sleep(2)
        pyautogui.click(x=1433, y=18)
    #Salvando o Arquivo - FIM
    #Removendo selecionados -  Inicio 
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários

        time.sleep(2)
        pyautogui.click(x=725, y=502)#Removendo selecionados

        time.sleep(1)
        pyautogui.click(x=351, y=632)#Botão - OK
    #Removendo selecionados -  FIM

        #Identificar o arquivo mais recente na pasta - Inicio
        caminho = r'C:\Users\Legalização2\Downloads'
        lista_arquivos = os.listdir(caminho)

        lista_datas = []
        for arquivos in lista_arquivos:
            #Descobrir a data desse arquivo
            data = os.path.getmtime(f'{caminho}/{arquivos}')
            lista_datas.append((data, arquivos))
    
        lista_datas.sort(reverse=True)   
        ultimo_arquivo = lista_datas[0]
        arquivo = ultimo_arquivo[1]
        #Fim

        #Validação do Arquivo - Inicio
        if 'Erika Goes' in arquivo:
            
            #Enviando Holerite por email - Inicio
            email = bd_df.loc[cod, 'Email'] #Localizar o e-mail

            mail = outlook.CreateItem(0)
            mail.To = email
            mail.subject = 'Holerite - Erika Goes'
            mail.Body = ''
            attachment  = f'{caminho}/{arquivo}'
            mail.Attachments.Add(attachment)
        
            mail.Send()
            
            print('Holerite enviado - Erika Goes')
        else:
            continue
            print('Erro no envio do Holerite da Erika Goes')

            #Enviando Holerite por email - Fim            
        #Validação do Arquivo - Fim

#Funcionario - Patricia Xavier         
    elif codigo==68:
        cod = 5   
        
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários
        
                #Buscando no sistema 
    #Inicio - 
        time.sleep(1)
        pyautogui.click(x=350, y=486)#Troque essa posição 

        time.sleep(1)
        pyautogui.click(x=720, y=402)

        time.sleep(1)
        pyautogui.click(x=351, y=632)
    #Fim
    #Salvando o Arquivo - Inicio
        time.sleep(1)
        pyautogui.click(x=629, y=646)#imprimir

        time.sleep(4)
        pyautogui.click(x=90, y=15)
    
        time.sleep(3)
        pyautogui.click(x=861, y=673)

        time.sleep(3)
        pyautogui.click(x=1034, y=687)

        time.sleep(3)
        pyautogui.click(x=204, y=376)

        time.sleep(3)
        pyautogui.write('Patricia Xavier')
        pyautogui.press('enter')

        time.sleep(2)
        pyautogui.click(x=1433, y=18)
    #Salvando o Arquivo - FIM
    #Removendo selecionados -  Inicio 
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários

        time.sleep(2)
        pyautogui.click(x=725, y=502)#Removendo selecionados

        time.sleep(1)
        pyautogui.click(x=351, y=632)#Botão - OK
    #Removendo selecionados -  FIM

        #Identificar o arquivo mais recente na pasta - Inicio
        caminho = r'C:\Users\Legalização2\Downloads'
        lista_arquivos = os.listdir(caminho)

        lista_datas = []
        for arquivos in lista_arquivos:
            #Descobrir a data desse arquivo
            data = os.path.getmtime(f'{caminho}/{arquivos}')
            lista_datas.append((data, arquivos))
    
        lista_datas.sort(reverse=True)   
        ultimo_arquivo = lista_datas[0]
        arquivo = ultimo_arquivo[1]
        #Fim

        #Validação do Arquivo - Inicio
        if 'Patricia Xavier' in arquivo:
            
            #Enviando Holerite por email - Inicio
            email = bd_df.loc[cod, 'Email'] #Localizar o e-mail

            mail = outlook.CreateItem(0)
            mail.To = email
            mail.subject = 'Holerite - Patricia Xavier'
            mail.Body = ''
            attachment  = f'{caminho}/{arquivo}'
            mail.Attachments.Add(attachment)
        
            mail.Send()
            
            print('Holerite enviado - Patricia Xavier')
        else:
            continue
            print('Erro no envio do Holerite da Patricia Xavier')

            #Enviando Holerite por email - Fim            
        #Validação do Arquivo - Fim
        
#Funcionario - Renato Alves         
    elif codigo==87:
        cod = 6   
        
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários
        
                #Buscando no sistema 
    #Inicio - 
        time.sleep(1)
        pyautogui.click(x=677, y=573)#Descendo a tela
        pyautogui.click(x=677, y=573)
        pyautogui.click(x=677, y=573)
        pyautogui.click(x=677, y=573)
        
        pyautogui.click(x=320, y=575)#Troque essa posição 

        time.sleep(1)
        pyautogui.click(x=720, y=402)

        time.sleep(1)
        pyautogui.click(x=351, y=632)
    #Fim
    #Salvando o Arquivo - Inicio
        time.sleep(1)
        pyautogui.click(x=629, y=646)#imprimir

        time.sleep(4)
        pyautogui.click(x=90, y=15)
    
        time.sleep(3)
        pyautogui.click(x=861, y=673)

        time.sleep(3)
        pyautogui.click(x=1034, y=687)

        time.sleep(3)
        pyautogui.click(x=204, y=376)

        time.sleep(3)
        pyautogui.write('Renato Alves')
        pyautogui.press('enter')

        time.sleep(2)
        pyautogui.click(x=1433, y=18)
    #Salvando o Arquivo - FIM
    #Removendo selecionados -  Inicio 
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários

        time.sleep(2)
        pyautogui.click(x=725, y=502)#Removendo selecionados

        time.sleep(1)
        pyautogui.click(x=351, y=632)#Botão - OK
    #Removendo selecionados -  FIM

        #Identificar o arquivo mais recente na pasta - Inicio
        caminho = r'C:\Users\Legalização2\Downloads'
        lista_arquivos = os.listdir(caminho)

        lista_datas = []
        for arquivos in lista_arquivos:
            #Descobrir a data desse arquivo
            data = os.path.getmtime(f'{caminho}/{arquivos}')
            lista_datas.append((data, arquivos))
    
        lista_datas.sort(reverse=True)   
        ultimo_arquivo = lista_datas[0]
        arquivo = ultimo_arquivo[1]
        #Fim

        #Validação do Arquivo - Inicio
        if 'Renato Alves' in arquivo:
            
            #Enviando Holerite por email - Inicio
            email = bd_df.loc[cod, 'Email'] #Localizar o e-mail

            mail = outlook.CreateItem(0)
            mail.To = email
            mail.subject = 'Holerite - Renato Alves'
            mail.Body = ''
            attachment  = f'{caminho}/{arquivo}'
            mail.Attachments.Add(attachment)
        
            mail.Send()
            
            print('Holerite enviado - Renato Alves')
        else:
            continue
            print('Erro no envio do Holerite da Renato Alves')

            #Enviando Holerite por email - Fim            
        #Validação do Arquivo - Fim
        
#Funcionario - Alice Cardoso         
    elif codigo==97:
        cod = 8   
        
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários
        
                #Buscando no sistema 
    #Inicio - 
        time.sleep(1)
        pyautogui.click(clicks=14, interval=0.25, x=677, y=573)#Descendo a tela-1
        
        pyautogui.click(x=350, y=571)#Troque essa posição 

        time.sleep(1)
        pyautogui.click(x=720, y=402)

        time.sleep(1)
        pyautogui.click(x=351, y=632)
    #Fim
    #Salvando o Arquivo - Inicio
        time.sleep(1)
        pyautogui.click(x=629, y=646)#imprimir

        time.sleep(4)
        pyautogui.click(x=90, y=15)
    
        time.sleep(3)
        pyautogui.click(x=861, y=673)

        time.sleep(3)
        pyautogui.click(x=1034, y=687)

        time.sleep(3)
        pyautogui.click(x=204, y=376)

        time.sleep(3)
        pyautogui.write('Alice Cardoso')
        pyautogui.press('enter')

        time.sleep(2)
        pyautogui.click(x=1433, y=18)
    #Salvando o Arquivo - FIM
    #Removendo selecionados -  Inicio 
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários

        time.sleep(2)
        pyautogui.click(x=725, y=502)#Removendo selecionados

        time.sleep(1)
        pyautogui.click(x=351, y=632)#Botão - OK
    #Removendo selecionados -  FIM

        #Identificar o arquivo mais recente na pasta - Inicio
        caminho = r'C:\Users\Legalização2\Downloads'
        lista_arquivos = os.listdir(caminho)

        lista_datas = []
        for arquivos in lista_arquivos:
            #Descobrir a data desse arquivo
            data = os.path.getmtime(f'{caminho}/{arquivos}')
            lista_datas.append((data, arquivos))
    
        lista_datas.sort(reverse=True)   
        ultimo_arquivo = lista_datas[0]
        arquivo = ultimo_arquivo[1]
        #Fim

        #Validação do Arquivo - Inicio
        if 'Alice Cardoso' in arquivo:
            
            #Enviando Holerite por email - Inicio
            email = bd_df.loc[cod, 'Email'] #Localizar o e-mail

            mail = outlook.CreateItem(0)
            mail.To = email
            mail.subject = 'Holerite - Alice Cardoso'
            mail.Body = ''
            attachment  = f'{caminho}/{arquivo}'
            mail.Attachments.Add(attachment)
        
            mail.Send()
            
            print('Holerite enviado - Alice Cardoso')
        else:
            continue
            print('Erro no envio do Holerite da Alice Cardoso')

            #Enviando Holerite por email - Fim            
        #Validação do Arquivo - Fim
        
#Funcionario - Rayane de Jesus         
    elif codigo==100:
        cod = 9   
        
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários
        
                #Buscando no sistema 
    #Inicio - 
        time.sleep(1)
        pyautogui.click(clicks=17, interval=0.25, x=677, y=573)#1 - Descendo a tela
        
        pyautogui.click(x=350, y=571)#Troque essa posição 

        time.sleep(1)
        pyautogui.click(x=720, y=402)

        time.sleep(1)
        pyautogui.click(x=351, y=632)
    #Fim
    #Salvando o Arquivo - Inicio
        time.sleep(1)
        pyautogui.click(x=629, y=646)#imprimir

        time.sleep(4)
        pyautogui.click(x=90, y=15)
    
        time.sleep(3)
        pyautogui.click(x=861, y=673)

        time.sleep(3)
        pyautogui.click(x=1034, y=687)

        time.sleep(3)
        pyautogui.click(x=204, y=376)

        time.sleep(3)
        pyautogui.write('Rayane de Jesus')
        pyautogui.press('enter')

        time.sleep(2)
        pyautogui.click(x=1433, y=18)
    #Salvando o Arquivo - FIM
    #Removendo selecionados -  Inicio 
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários

        time.sleep(2)
        pyautogui.click(x=725, y=502)#Removendo selecionados

        time.sleep(1)
        pyautogui.click(x=351, y=632)#Botão - OK
    #Removendo selecionados -  FIM

        #Identificar o arquivo mais recente na pasta - Inicio
        caminho = r'C:\Users\Legalização2\Downloads'
        lista_arquivos = os.listdir(caminho)

        lista_datas = []
        for arquivos in lista_arquivos:
            #Descobrir a data desse arquivo
            data = os.path.getmtime(f'{caminho}/{arquivos}')
            lista_datas.append((data, arquivos))
    
        lista_datas.sort(reverse=True)   
        ultimo_arquivo = lista_datas[0]
        arquivo = ultimo_arquivo[1]
        #Fim

        #Validação do Arquivo - Inicio
        if 'Rayane de Jesus' in arquivo:
            
            #Enviando Holerite por email - Inicio
            email = bd_df.loc[cod, 'Email'] #Localizar o e-mail

            mail = outlook.CreateItem(0)
            mail.To = email
            mail.subject = 'Holerite - Rayane de Jesus'
            mail.Body = ''
            attachment  = f'{caminho}/{arquivo}'
            mail.Attachments.Add(attachment)
        
            mail.Send()
            
            print('Holerite enviado - Rayane de Jesus')
        else:
            continue
            print('Erro no envio do Holerite da Rayane de Jesus')

            #Enviando Holerite por email - Fim            
        #Validação do Arquivo - Fim
        
#Funcionario - Nayara Cavalcante         
    elif codigo==101:
        cod = 10   
        
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários
        
                #Buscando no sistema 
    #Inicio - 
        time.sleep(1)
        pyautogui.click(clicks=18, interval=0.25, x=677, y=573)#1 - Descendo a tela
        
        pyautogui.click(x=350, y=571)#Troque essa posição 

        time.sleep(1)
        pyautogui.click(x=720, y=402)

        time.sleep(1)
        pyautogui.click(x=351, y=632)
    #Fim
    #Salvando o Arquivo - Inicio
        time.sleep(1)
        pyautogui.click(x=629, y=646)#imprimir

        time.sleep(4)
        pyautogui.click(x=90, y=15)
    
        time.sleep(3)
        pyautogui.click(x=861, y=673)

        time.sleep(3)
        pyautogui.click(x=1034, y=687)

        time.sleep(3)
        pyautogui.click(x=204, y=376)

        time.sleep(3)
        pyautogui.write('Nayara Cavalcante')
        pyautogui.press('enter')

        time.sleep(2)
        pyautogui.click(x=1433, y=18)
    #Salvando o Arquivo - FIM
    #Removendo selecionados -  Inicio 
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários

        time.sleep(2)
        pyautogui.click(x=725, y=502)#Removendo selecionados

        time.sleep(1)
        pyautogui.click(x=351, y=632)#Botão - OK
    #Removendo selecionados -  FIM

        #Identificar o arquivo mais recente na pasta - Inicio
        caminho = r'C:\Users\Legalização2\Downloads'
        lista_arquivos = os.listdir(caminho)

        lista_datas = []
        for arquivos in lista_arquivos:
            #Descobrir a data desse arquivo
            data = os.path.getmtime(f'{caminho}/{arquivos}')
            lista_datas.append((data, arquivos))
    
        lista_datas.sort(reverse=True)   
        ultimo_arquivo = lista_datas[0]
        arquivo = ultimo_arquivo[1]
        #Fim

        #Validação do Arquivo - Inicio
        if 'Nayara Cavalcante' in arquivo:
            
            #Enviando Holerite por email - Inicio
            email = bd_df.loc[cod, 'Email'] #Localizar o e-mail

            mail = outlook.CreateItem(0)
            mail.To = email
            mail.subject = 'Holerite - Nayara Cavalcante'
            mail.Body = ''
            attachment  = f'{caminho}/{arquivo}'
            mail.Attachments.Add(attachment)
        
            mail.Send()
            
            print('Holerite enviado - Nayara Cavalcante')
        else:
            continue
            print('Erro no envio do Holerite da Nayara Cavalcante')

            #Enviando Holerite por email - Fim            
        #Validação do Arquivo - Fim
        
#Funcionario - Giovana Maria         
    elif codigo==102:
        cod = 11   
        
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários
        
                #Buscando no sistema 
    #Inicio - 
        time.sleep(1)
        pyautogui.click(clicks=19, interval=0.25, x=677, y=573)#1 - Descendo a tela
        
        pyautogui.click(x=350, y=571)#Troque essa posição 

        time.sleep(1)
        pyautogui.click(x=720, y=402)

        time.sleep(1)
        pyautogui.click(x=351, y=632)
    #Fim
    #Salvando o Arquivo - Inicio
        time.sleep(1)
        pyautogui.click(x=629, y=646)#imprimir

        time.sleep(4)
        pyautogui.click(x=90, y=15)
    
        time.sleep(3)
        pyautogui.click(x=861, y=673)

        time.sleep(3)
        pyautogui.click(x=1034, y=687)

        time.sleep(3)
        pyautogui.click(x=204, y=376)

        time.sleep(3)
        pyautogui.write('Giovana Maria')
        pyautogui.press('enter')

        time.sleep(2)
        pyautogui.click(x=1433, y=18)
    #Salvando o Arquivo - FIM
    #Removendo selecionados -  Inicio 
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários

        time.sleep(2)
        pyautogui.click(x=725, y=502)#Removendo selecionados

        time.sleep(1)
        pyautogui.click(x=351, y=632)#Botão - OK
    #Removendo selecionados -  FIM

        #Identificar o arquivo mais recente na pasta - Inicio
        caminho = r'C:\Users\Legalização2\Downloads'
        lista_arquivos = os.listdir(caminho)

        lista_datas = []
        for arquivos in lista_arquivos:
            #Descobrir a data desse arquivo
            data = os.path.getmtime(f'{caminho}/{arquivos}')
            lista_datas.append((data, arquivos))
    
        lista_datas.sort(reverse=True)   
        ultimo_arquivo = lista_datas[0]
        arquivo = ultimo_arquivo[1]
        #Fim

        #Validação do Arquivo - Inicio
        if 'Giovana Maria' in arquivo:
            
            #Enviando Holerite por email - Inicio
            email = bd_df.loc[cod, 'Email'] #Localizar o e-mail

            mail = outlook.CreateItem(0)
            mail.To = email
            mail.subject = 'Holerite - Giovana Maria'
            mail.Body = ''
            attachment  = f'{caminho}/{arquivo}'
            mail.Attachments.Add(attachment)
        
            mail.Send()
            
            print('Holerite enviado - Giovana Maria')
        else:
            continue
            print('Erro no envio do Holerite da Giovana Maria')

            #Enviando Holerite por email - Fim            
        #Validação do Arquivo - Fim
        
#Funcionario - Larissa Felipini         
    elif codigo==103:
        cod = 12   
        
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários
        
                #Buscando no sistema 
    #Inicio - 
        time.sleep(1)
        pyautogui.click(clicks=20, interval=0.25, x=677, y=573)#1 - Descendo a tela
        
        pyautogui.click(x=350, y=571)#Troque essa posição 

        time.sleep(1)
        pyautogui.click(x=720, y=402)

        time.sleep(1)
        pyautogui.click(x=351, y=632)
    #Fim
    #Salvando o Arquivo - Inicio
        time.sleep(1)
        pyautogui.click(x=629, y=646)#imprimir

        time.sleep(4)
        pyautogui.click(x=90, y=15)
    
        time.sleep(3)
        pyautogui.click(x=861, y=673)

        time.sleep(3)
        pyautogui.click(x=1034, y=687)

        time.sleep(3)
        pyautogui.click(x=204, y=376)

        time.sleep(3)
        pyautogui.write('Larissa Felipini')
        pyautogui.press('enter')

        time.sleep(2)
        pyautogui.click(x=1433, y=18)
    #Salvando o Arquivo - FIM
    #Removendo selecionados -  Inicio 
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários

        time.sleep(2)
        pyautogui.click(x=725, y=502)#Removendo selecionados

        time.sleep(1)
        pyautogui.click(x=351, y=632)#Botão - OK
    #Removendo selecionados -  FIM

        #Identificar o arquivo mais recente na pasta - Inicio
        caminho = r'C:\Users\Legalização2\Downloads'
        lista_arquivos = os.listdir(caminho)

        lista_datas = []
        for arquivos in lista_arquivos:
            #Descobrir a data desse arquivo
            data = os.path.getmtime(f'{caminho}/{arquivos}')
            lista_datas.append((data, arquivos))
    
        lista_datas.sort(reverse=True)   
        ultimo_arquivo = lista_datas[0]
        arquivo = ultimo_arquivo[1]
        #Fim

        #Validação do Arquivo - Inicio
        if 'Larissa Felipini' in arquivo:
            
            #Enviando Holerite por email - Inicio
            email = bd_df.loc[cod, 'Email'] #Localizar o e-mail

            mail = outlook.CreateItem(0)
            mail.To = email
            mail.subject = 'Holerite - Larissa Felipini'
            mail.Body = ''
            attachment  = f'{caminho}/{arquivo}'
            mail.Attachments.Add(attachment)
        
            mail.Send()
            
            print('Holerite enviado - Larissa Felipini')
        else:
            continue
            print('Erro no envio do Holerite da Larissa Felipini')

            #Enviando Holerite por email - Fim            
        #Validação do Arquivo - Fim
        
#Funcionario - Lauro Henrique         
    elif codigo==104:
        cod = 13   
        
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários
        
                #Buscando no sistema 
    #Inicio - 
        time.sleep(1)
        pyautogui.click(clicks=21, interval=0.25, x=677, y=573)#1 - Descendo a tela
        
        pyautogui.click(x=350, y=571)#Troque essa posição 

        time.sleep(1)
        pyautogui.click(x=720, y=402)

        time.sleep(1)
        pyautogui.click(x=351, y=632)
    #Fim
    #Salvando o Arquivo - Inicio
        time.sleep(1)
        pyautogui.click(x=629, y=646)#imprimir

        time.sleep(4)
        pyautogui.click(x=90, y=15)
    
        time.sleep(3)
        pyautogui.click(x=861, y=673)

        time.sleep(3)
        pyautogui.click(x=1034, y=687)

        time.sleep(3)
        pyautogui.click(x=204, y=376)

        time.sleep(3)
        pyautogui.write('Lauro Henrique')
        pyautogui.press('enter')

        time.sleep(2)
        pyautogui.click(x=1433, y=18)
    #Salvando o Arquivo - FIM
    #Removendo selecionados -  Inicio 
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários

        time.sleep(2)
        pyautogui.click(x=725, y=502)#Removendo selecionados

        time.sleep(1)
        pyautogui.click(x=351, y=632)#Botão - OK
    #Removendo selecionados -  FIM

        #Identificar o arquivo mais recente na pasta - Inicio
        caminho = r'C:\Users\Legalização2\Downloads'
        lista_arquivos = os.listdir(caminho)

        lista_datas = []
        for arquivos in lista_arquivos:
            #Descobrir a data desse arquivo
            data = os.path.getmtime(f'{caminho}/{arquivos}')
            lista_datas.append((data, arquivos))
    
        lista_datas.sort(reverse=True)   
        ultimo_arquivo = lista_datas[0]
        arquivo = ultimo_arquivo[1]
        #Fim

        #Validação do Arquivo - Inicio
        if 'Lauro Henrique' in arquivo:
            
            #Enviando Holerite por email - Inicio
            email = bd_df.loc[cod, 'Email'] #Localizar o e-mail

            mail = outlook.CreateItem(0)
            mail.To = email
            mail.subject = 'Holerite - Lauro Henrique'
            mail.Body = ''
            attachment  = f'{caminho}/{arquivo}'
            mail.Attachments.Add(attachment)
        
            mail.Send()
            
            print('Holerite enviado - Lauro Henrique')
        else:
            continue
            print('Erro no envio do Holerite da Lauro Henrique')

            #Enviando Holerite por email - Fim            
        #Validação do Arquivo - Fim
        
#Funcionario - Priscila Vitoria         
    elif codigo==106:
        cod = 14   
        
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários
        
                #Buscando no sistema 
    #Inicio - 
        time.sleep(1)
        pyautogui.click(clicks=23, interval=0.25, x=677, y=573)#1 - Descendo a tela
        
        pyautogui.click(x=350, y=571)#Troque essa posição 

        time.sleep(1)
        pyautogui.click(x=720, y=402)

        time.sleep(1)
        pyautogui.click(x=351, y=632)
    #Fim
    #Salvando o Arquivo - Inicio
        time.sleep(1)
        pyautogui.click(x=629, y=646)#imprimir

        time.sleep(4)
        pyautogui.click(x=90, y=15)
    
        time.sleep(3)
        pyautogui.click(x=861, y=673)

        time.sleep(3)
        pyautogui.click(x=1034, y=687)

        time.sleep(3)
        pyautogui.click(x=204, y=376)

        time.sleep(3)
        pyautogui.write('Priscila Vitoria')
        pyautogui.press('enter')

        time.sleep(2)
        pyautogui.click(x=1433, y=18)
    #Salvando o Arquivo - FIM
    #Removendo selecionados -  Inicio 
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários

        time.sleep(2)
        pyautogui.click(x=725, y=502)#Removendo selecionados

        time.sleep(1)
        pyautogui.click(x=351, y=632)#Botão - OK
    #Removendo selecionados -  FIM

        #Identificar o arquivo mais recente na pasta - Inicio
        caminho = r'C:\Users\Legalização2\Downloads'
        lista_arquivos = os.listdir(caminho)

        lista_datas = []
        for arquivos in lista_arquivos:
            #Descobrir a data desse arquivo
            data = os.path.getmtime(f'{caminho}/{arquivos}')
            lista_datas.append((data, arquivos))
    
        lista_datas.sort(reverse=True)   
        ultimo_arquivo = lista_datas[0]
        arquivo = ultimo_arquivo[1]
        #Fim

        #Validação do Arquivo - Inicio
        if 'Priscila Vitoria' in arquivo:
            
            #Enviando Holerite por email - Inicio
            email = bd_df.loc[cod, 'Email'] #Localizar o e-mail

            mail = outlook.CreateItem(0)
            mail.To = email
            mail.subject = 'Holerite - Priscila Vitoria'
            mail.Body = ''
            attachment  = f'{caminho}/{arquivo}'
            mail.Attachments.Add(attachment)
        
            mail.Send()
            
            print('Holerite enviado - Priscila Vitoria')
        else:
            continue
            print('Erro no envio do Holerite da Priscila Vitoria')

            #Enviando Holerite por email - Fim            
        #Validação do Arquivo - Fim
        
#Funcionario - Weslley Gomes         
    elif codigo==107:
        cod = 15   
        
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários
        
                #Buscando no sistema 
    #Inicio - 
        time.sleep(1)
        pyautogui.click(clicks=24, interval=0.25, x=677, y=573)#1 - Descendo a tela
        
        pyautogui.click(x=350, y=571)#Troque essa posição 

        time.sleep(1)
        pyautogui.click(x=720, y=402)

        time.sleep(1)
        pyautogui.click(x=351, y=632)
    #Fim
    #Salvando o Arquivo - Inicio
        time.sleep(1)
        pyautogui.click(x=629, y=646)#imprimir

        time.sleep(4)
        pyautogui.click(x=90, y=15)
    
        time.sleep(3)
        pyautogui.click(x=861, y=673)

        time.sleep(3)
        pyautogui.click(x=1034, y=687)

        time.sleep(3)
        pyautogui.click(x=204, y=376)

        time.sleep(3)
        pyautogui.write('Weslley Gomes')
        pyautogui.press('enter')

        time.sleep(2)
        pyautogui.click(x=1433, y=18)
    #Salvando o Arquivo - FIM
    #Removendo selecionados -  Inicio 
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários

        time.sleep(2)
        pyautogui.click(x=725, y=502)#Removendo selecionados

        time.sleep(1)
        pyautogui.click(x=351, y=632)#Botão - OK
    #Removendo selecionados -  FIM

        #Identificar o arquivo mais recente na pasta - Inicio
        caminho = r'C:\Users\Legalização2\Downloads'
        lista_arquivos = os.listdir(caminho)

        lista_datas = []
        for arquivos in lista_arquivos:
            #Descobrir a data desse arquivo
            data = os.path.getmtime(f'{caminho}/{arquivos}')
            lista_datas.append((data, arquivos))
    
        lista_datas.sort(reverse=True)   
        ultimo_arquivo = lista_datas[0]
        arquivo = ultimo_arquivo[1]
        #Fim

        #Validação do Arquivo - Inicio
        if 'Weslley Gomes' in arquivo:
            
            #Enviando Holerite por email - Inicio
            email = bd_df.loc[cod, 'Email'] #Localizar o e-mail

            mail = outlook.CreateItem(0)
            mail.To = email
            mail.subject = 'Holerite - Weslley Gomes'
            mail.Body = ''
            attachment  = f'{caminho}/{arquivo}'
            mail.Attachments.Add(attachment)
        
            mail.Send()
            
            print('Holerite enviado - Weslley Gomes')
        else:
            continue
            print('Erro no envio do Holerite da Weslley Gomes')

            #Enviando Holerite por email - Fim            
        #Validação do Arquivo - Fim
        
#Funcionario - Vallery Sanchez         
    elif codigo==108:
        cod = 16   
        
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários
        
                #Buscando no sistema 
    #Inicio - 
        time.sleep(1)
        pyautogui.click(clicks=25, interval=0.25, x=677, y=573)#1 - Descendo a tela
        
        pyautogui.click(x=350, y=571)#Troque essa posição 

        time.sleep(1)
        pyautogui.click(x=720, y=402)

        time.sleep(1)
        pyautogui.click(x=351, y=632)
    #Fim
    #Salvando o Arquivo - Inicio
        time.sleep(1)
        pyautogui.click(x=629, y=646)#imprimir

        time.sleep(4)
        pyautogui.click(x=90, y=15)
    
        time.sleep(3)
        pyautogui.click(x=861, y=673)

        time.sleep(3)
        pyautogui.click(x=1034, y=687)

        time.sleep(3)
        pyautogui.click(x=204, y=376)

        time.sleep(3)
        pyautogui.write('Vallery Sanchez')
        pyautogui.press('enter')

        time.sleep(2)
        pyautogui.click(x=1433, y=18)
    #Salvando o Arquivo - FIM
    #Removendo selecionados -  Inicio 
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários

        time.sleep(2)
        pyautogui.click(x=725, y=502)#Removendo selecionados

        time.sleep(1)
        pyautogui.click(x=351, y=632)#Botão - OK
    #Removendo selecionados -  FIM

        #Identificar o arquivo mais recente na pasta - Inicio
        caminho = r'C:\Users\Legalização2\Downloads'
        lista_arquivos = os.listdir(caminho)

        lista_datas = []
        for arquivos in lista_arquivos:
            #Descobrir a data desse arquivo
            data = os.path.getmtime(f'{caminho}/{arquivos}')
            lista_datas.append((data, arquivos))
    
        lista_datas.sort(reverse=True)   
        ultimo_arquivo = lista_datas[0]
        arquivo = ultimo_arquivo[1]
        #Fim

        #Validação do Arquivo - Inicio
        if 'Vallery Sanchez' in arquivo:
            
            #Enviando Holerite por email - Inicio
            email = bd_df.loc[cod, 'Email'] #Localizar o e-mail

            mail = outlook.CreateItem(0)
            mail.To = email
            mail.subject = 'Holerite - Vallery Sanchez'
            mail.Body = ''
            attachment  = f'{caminho}/{arquivo}'
            mail.Attachments.Add(attachment)
        
            mail.Send()
            
            print('Holerite enviado - Vallery Sanchez')
        else:
            continue
            print('Erro no envio do Holerite da Vallery Sanchez')

            #Enviando Holerite por email - Fim            
        #Validação do Arquivo - Fim
        
#Funcionario - Patricia Pomponet         
    elif codigo==1001:
        cod = 17   
        
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários
        
                #Buscando no sistema 
    #Inicio - 
        time.sleep(1)
        pyautogui.click(clicks=26, interval=0.25, x=677, y=573)#1 - Descendo a tela
        
        pyautogui.click(x=350, y=571)#Troque essa posição 

        time.sleep(1)
        pyautogui.click(x=720, y=402)

        time.sleep(1)
        pyautogui.click(x=351, y=632)
    #Fim
    #Salvando o Arquivo - Inicio
        time.sleep(1)
        pyautogui.click(x=629, y=646)#imprimir

        time.sleep(4)
        pyautogui.click(x=90, y=15)
    
        time.sleep(3)
        pyautogui.click(x=861, y=673)

        time.sleep(3)
        pyautogui.click(x=1034, y=687)

        time.sleep(3)
        pyautogui.click(x=204, y=376)

        time.sleep(3)
        pyautogui.write('Patricia Pomponet')
        pyautogui.press('enter')

        time.sleep(2)
        pyautogui.click(x=1433, y=18)
    #Salvando o Arquivo - FIM
    #Removendo selecionados -  Inicio 
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários

        time.sleep(2)
        pyautogui.click(x=725, y=502)#Removendo selecionados

        time.sleep(1)
        pyautogui.click(x=351, y=632)#Botão - OK
    #Removendo selecionados -  FIM

        #Identificar o arquivo mais recente na pasta - Inicio
        caminho = r'C:\Users\Legalização2\Downloads'
        lista_arquivos = os.listdir(caminho)

        lista_datas = []
        for arquivos in lista_arquivos:
            #Descobrir a data desse arquivo
            data = os.path.getmtime(f'{caminho}/{arquivos}')
            lista_datas.append((data, arquivos))
    
        lista_datas.sort(reverse=True)   
        ultimo_arquivo = lista_datas[0]
        arquivo = ultimo_arquivo[1]
        #Fim

        #Validação do Arquivo - Inicio
        if 'Patricia Pomponet' in arquivo:
            
            #Enviando Holerite por email - Inicio
            email = bd_df.loc[cod, 'Email'] #Localizar o e-mail

            mail = outlook.CreateItem(0)
            mail.To = email
            mail.subject = 'Holerite - Patricia Pomponet'
            mail.Body = ''
            attachment  = f'{caminho}/{arquivo}'
            mail.Attachments.Add(attachment)
        
            mail.Send()
            
            print('Holerite enviado - Patricia Pomponet')
        else:
            continue
            print('Erro no envio do Holerite da Patricia Pomponet')

            #Enviando Holerite por email - Fim            
        #Validação do Arquivo - Fim
        
#Funcionario - Julia Bataglioli         
    elif codigo==1004:
        cod = 18   
        
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários
        
                #Buscando no sistema 
    #Inicio - 
        time.sleep(1)
        pyautogui.click(clicks=29, interval=0.25, x=677, y=573)#1 - Descendo a tela
        
        pyautogui.click(x=350, y=571)#Troque essa posição 

        time.sleep(1)
        pyautogui.click(x=720, y=402)

        time.sleep(1)
        pyautogui.click(x=351, y=632)
    #Fim
    #Salvando o Arquivo - Inicio
        time.sleep(1)
        pyautogui.click(x=629, y=646)#imprimir

        time.sleep(4)
        pyautogui.click(x=90, y=15)
    
        time.sleep(3)
        pyautogui.click(x=861, y=673)

        time.sleep(3)
        pyautogui.click(x=1034, y=687)

        time.sleep(3)
        pyautogui.click(x=204, y=376)

        time.sleep(3)
        pyautogui.write('Julia Bataglioli')
        pyautogui.press('enter')

        time.sleep(2)
        pyautogui.click(x=1433, y=18)
    #Salvando o Arquivo - FIM
    #Removendo selecionados -  Inicio 
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários

        time.sleep(2)
        pyautogui.click(x=725, y=502)#Removendo selecionados

        time.sleep(1)
        pyautogui.click(x=351, y=632)#Botão - OK
    #Removendo selecionados -  FIM

        #Identificar o arquivo mais recente na pasta - Inicio
        caminho = r'C:\Users\Legalização2\Downloads'
        lista_arquivos = os.listdir(caminho)

        lista_datas = []
        for arquivos in lista_arquivos:
            #Descobrir a data desse arquivo
            data = os.path.getmtime(f'{caminho}/{arquivos}')
            lista_datas.append((data, arquivos))
    
        lista_datas.sort(reverse=True)   
        ultimo_arquivo = lista_datas[0]
        arquivo = ultimo_arquivo[1]
        #Fim

        #Validação do Arquivo - Inicio
        if 'Julia Bataglioli' in arquivo:
            
            #Enviando Holerite por email - Inicio
            email = bd_df.loc[cod, 'Email'] #Localizar o e-mail

            mail = outlook.CreateItem(0)
            mail.To = email
            mail.subject = 'Holerite - Julia Bataglioli'
            mail.Body = ''
            attachment  = f'{caminho}/{arquivo}'
            mail.Attachments.Add(attachment)
        
            mail.Send()
            
            print('Holerite enviado - Julia Bataglioli')
        else:
            continue
            print('Erro no envio do Holerite da Julia Bataglioli')

            #Enviando Holerite por email - Fim            
        #Validação do Arquivo - Fim
        
#Funcionario - Elenicia Ramalho         
    elif codigo==90:
        cod = 7   
        
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários
        
                #Buscando no sistema 
    #Inicio - 
        time.sleep(1)
        pyautogui.click(clicks=29, interval=0.25, x=677, y=573)#1 - Descendo a tela
        
        pyautogui.click(x=350, y=571)#Troque essa posição 

        time.sleep(1)
        pyautogui.click(x=720, y=402)

        time.sleep(1)
        pyautogui.click(x=351, y=632)
    #Fim
    #Salvando o Arquivo - Inicio
        time.sleep(1)
        pyautogui.click(x=629, y=646)#imprimir

        time.sleep(4)
        pyautogui.click(x=90, y=15)
    
        time.sleep(3)
        pyautogui.click(x=861, y=673)

        time.sleep(3)
        pyautogui.click(x=1034, y=687)

        time.sleep(3)
        pyautogui.click(x=204, y=376)

        time.sleep(3)
        pyautogui.write('Elenicia Ramalho')
        pyautogui.press('enter')

        time.sleep(2)
        pyautogui.click(x=1433, y=18)
    #Salvando o Arquivo - FIM
    #Removendo selecionados -  Inicio 
        time.sleep(1)
        pyautogui.click(x=598, y=328)#Botão Funcionários

        time.sleep(2)
        pyautogui.click(x=725, y=502)#Removendo selecionados

        time.sleep(1)
        pyautogui.click(x=351, y=632)#Botão - OK
    #Removendo selecionados -  FIM

        #Identificar o arquivo mais recente na pasta - Inicio
        caminho = r'C:\Users\Legalização2\Downloads'
        lista_arquivos = os.listdir(caminho)

        lista_datas = []
        for arquivos in lista_arquivos:
            #Descobrir a data desse arquivo
            data = os.path.getmtime(f'{caminho}/{arquivos}')
            lista_datas.append((data, arquivos))
    
        lista_datas.sort(reverse=True)   
        ultimo_arquivo = lista_datas[0]
        arquivo = ultimo_arquivo[1]
        #Fim

        #Validação do Arquivo - Inicio
        if 'Elenicia Ramalho' in arquivo:
            
            #Enviando Holerite por email - Inicio
            email = bd_df.loc[cod, 'Email'] #Localizar o e-mail

            mail = outlook.CreateItem(0)
            mail.To = email
            mail.subject = 'Holerite - Elenicia Ramalho'
            mail.Body = ''
            attachment  = f'{caminho}/{arquivo}'
            mail.Attachments.Add(attachment)
        
            mail.Send()
            
            print('Holerite enviado - Elenicia Ramalho')
        else:
            continue
            print('Erro no envio do Holerite da Elenicia Ramalho')

            #Enviando Holerite por email - Fim            
        #Validação do Arquivo - Fim
# Out:
# Holerite enviado - Eliana França
# Holerite enviado - Regina Felipini
# Holerite enviado - Juliana Gomes
# Holerite enviado - Miriam Vieira
# Holerite enviado - Erika Goes
# Holerite enviado - Patricia Xavier
# Holerite enviado - Renato Alves
# Holerite enviado - Elenicia Ramalho
# Holerite enviado - Alice Cardoso
# Holerite enviado - Rayane de Jesus
# Holerite enviado - Nayara Cavalcante
# Holerite enviado - Giovana Maria
# Holerite enviado - Larissa Felipini
# Holerite enviado - Lauro Henrique
# Holerite enviado - Priscila Vitoria
# Holerite enviado - Weslley Gomes
# Holerite enviado - Vallery Sanchez
# Holerite enviado - Patricia Pomponet
# Holerite enviado - Julia Bataglioli

# %%
pyautogui.position()
# Out:
# Point(x=350, y=571)
